# %% [markdown]
# # DATAFRAMES

# %% [markdown]
# Dataframes : A table of data that contains a collection of rows and columns.
# They are 2 dimensional (labelled indices and columns).
# Each column in a dataframe is a series.

# %%
import pandas as pd
import numpy as np

# %%
name = ['Althaf', 'Bhushan', 'Shubham']
age = [20, 25, 30]
marital_status = [False, False, False]

# %%
df = pd.DataFrame({'name': name, 'age': age, 'marital_status' : marital_status})

# %%
df
# Out:
#       name  age  marital_status
# 0   Althaf   20           False
# 1  Bhushan   25           False
# 2  Shubham   30           False

# %%
# Check the dimensions

df.ndim
# Out:
# 2

# %%
# Check the shape

df.shape
# Out:
# (3, 3)

# %%
df.name
# Out:
# 0     Althaf
# 1    Bhushan
# 2    Shubham
# Name: name, dtype: object

# %%
df.dtypes
# Out:
# name              object
# age                int64
# marital_status      bool
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            3 non-null      object
#  1   age             3 non-null      int64
#  2   marital_status  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
df.info(memory_usage= 'True')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            3 non-null      object
#  1   age             3 non-null      int64
#  2   marital_status  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
df.info(memory_usage= 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            3 non-null      object
#  1   age             3 non-null      int64
#  2   marital_status  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 346.0 bytes

# %%
# Importing nutrition dataset from source

# %%
url = 'https://andybek.com/pandas-nutrition'

# %%
nutrition = pd.read_csv(url)

# %%
nutrition.head()
# Out:
#    Unnamed: 0             name serving_size  calories total_fat saturated_fat  \
# 0           0       Cornstarch        100 g       381      0.1g           NaN
# 1           1     Nuts, pecans        100 g       691       72g          6.2g
# 2           2    Eggplant, raw        100 g        25      0.2g           NaN
# 3           3   Teff, uncooked        100 g       367      2.4g          0.4g
# 4           4  Sherbet, orange        100 g       144        2g          1.2g
#
#   cholesterol    sodium  choline     folate  ...      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...   2.38 g
# 4         1mg  46.00 mg   7.7 mg   4.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# ...

# %%
nutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 77 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   8789 non-null   int64
#  1   name                         8789 non-null   object
#  2   serving_size                 8789 non-null   object
#  3   calories                     8789 non-null   int64
#  4   total_fat                    8789 non-null   object
#  5   saturated_fat                7199 non-null   object
#  6   cholesterol                  8789 non-null   object
#  7   sodium                       8789 non-null   object
#  8   choline                      8789 non-null   object
#  9   folate                       8789 non-null   object
#  10  folic_acid                   8789 non-null   object
#  11  niacin                       8789 non-null   object
#  12  pantothenic_acid             8789 non-null   object
# ...

# %%
nutrition.info(verbose=False, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Columns: 77 entries, Unnamed: 0 to water
# dtypes: int64(3), object(74)
# memory usage: 39.2 MB

# %%
# Removing a duplicate index

# %%
nutrition.head(10)
# Out:
#    Unnamed: 0                name serving_size  calories total_fat  \
# 0           0          Cornstarch        100 g       381      0.1g
# 1           1        Nuts, pecans        100 g       691       72g
# 2           2       Eggplant, raw        100 g        25      0.2g
# 3           3      Teff, uncooked        100 g       367      2.4g
# 4           4     Sherbet, orange        100 g       144        2g
# 5           5    Cauliflower, raw        100 g        25      0.3g
# 6           6    Taro leaves, raw        100 g        42      0.7g
# 7           7   Lamb, raw, ground        100 g       282       23g
# 8           8   Cheese, camembert        100 g       300       24g
# 9           9  Vegetarian fillets        100 g       290       18g
#
#   saturated_fat cholesterol     sodium  choline      folate  ...      fat  \
# 0           NaN           0    9.00 mg   0.4 mg    0.00 mcg  ...   0.05 g
# 1          6.2g           0    0.00 mg  40.5 mg   22.00 mcg  ...  71.97 g
# ...

# %%
nutrition.iloc[:,1:].head(10)
# Out:
#                  name serving_size  calories total_fat saturated_fat  \
# 0          Cornstarch        100 g       381      0.1g           NaN
# 1        Nuts, pecans        100 g       691       72g          6.2g
# 2       Eggplant, raw        100 g        25      0.2g           NaN
# 3      Teff, uncooked        100 g       367      2.4g          0.4g
# 4     Sherbet, orange        100 g       144        2g          1.2g
# 5    Cauliflower, raw        100 g        25      0.3g          0.1g
# 6    Taro leaves, raw        100 g        42      0.7g          0.2g
# 7   Lamb, raw, ground        100 g       282       23g           10g
# 8   Cheese, camembert        100 g       300       24g           15g
# 9  Vegetarian fillets        100 g       290       18g          2.8g
#
#   cholesterol     sodium  choline      folate folic_acid  ...      fat  \
# 0           0    9.00 mg   0.4 mg    0.00 mcg   0.00 mcg  ...   0.05 g
# ...

# %%
nutrition.drop('Unnamed: 0', axis=1)
# Out:
#                                                    name serving_size  \
# 0                                            Cornstarch        100 g
# 1                                          Nuts, pecans        100 g
# 2                                         Eggplant, raw        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785  Lamb, cooked, separable lean only, composite o...        100 g
# 8786  Lamb, raw, separable lean and fat, composite o...        100 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# ...

# %%
nutrition.head(10)
# Out:
#    Unnamed: 0                name serving_size  calories total_fat  \
# 0           0          Cornstarch        100 g       381      0.1g
# 1           1        Nuts, pecans        100 g       691       72g
# 2           2       Eggplant, raw        100 g        25      0.2g
# 3           3      Teff, uncooked        100 g       367      2.4g
# 4           4     Sherbet, orange        100 g       144        2g
# 5           5    Cauliflower, raw        100 g        25      0.3g
# 6           6    Taro leaves, raw        100 g        42      0.7g
# 7           7   Lamb, raw, ground        100 g       282       23g
# 8           8   Cheese, camembert        100 g       300       24g
# 9           9  Vegetarian fillets        100 g       290       18g
#
#   saturated_fat cholesterol     sodium  choline      folate  ...      fat  \
# 0           NaN           0    9.00 mg   0.4 mg    0.00 mcg  ...   0.05 g
# 1          6.2g           0    0.00 mg  40.5 mg   22.00 mcg  ...  71.97 g
# ...

# %%
nutrition.set_index('Unnamed: 0')
# Out:
#                                                          name serving_size  \
# Unnamed: 0
# 0                                                  Cornstarch        100 g
# 1                                                Nuts, pecans        100 g
# 2                                               Eggplant, raw        100 g
# 3                                              Teff, uncooked        100 g
# 4                                             Sherbet, orange        100 g
# ...                                                       ...          ...
# 8784        Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785        Lamb, cooked, separable lean only, composite o...        100 g
# 8786        Lamb, raw, separable lean and fat, composite o...        100 g
# 8787        Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788        Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
# ...

# %%
url
# Out:
# 'https://andybek.com/pandas-nutrition'

# %%
nutrition = pd.read_csv(url, index_col=[1])

# %%
nutrition.head(5)
# Out:
#                  Unnamed: 0 serving_size  calories total_fat saturated_fat  \
# name
# Cornstarch                0        100 g       381      0.1g           NaN
# Nuts, pecans              1        100 g       691       72g          6.2g
# Eggplant, raw             2        100 g        25      0.2g           NaN
# Teff, uncooked            3        100 g       367      2.4g          0.4g
# Sherbet, orange           4        100 g       144        2g          1.2g
#
#                 cholesterol    sodium  choline     folate folic_acid  ...  \
# name                                                                  ...
# Cornstarch                0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...
# Nuts, pecans              0   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...
# Eggplant, raw             0   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...
# Teff, uncooked            0  12.00 mg  13.1 mg          0          0  ...
# ...

# %%
nutrition.drop('Unnamed: 0', axis=1, inplace = True)

# %%
nutrition.head(5)
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
# Sample() : Return a random row of data

# %%
nutrition.sample()
# Out:
#                         serving_size  calories total_fat saturated_fat  \
# name
# Picnic loaf, beef, pork        100 g       232       17g          6.1g
#
#                         cholesterol      sodium choline    folate folic_acid  \
# name
# Picnic loaf, beef, pork        38mg  1164.00 mg       0  2.00 mcg   0.00 mcg
#
#                            niacin  ...      fat saturated_fatty_acids  \
# name                               ...
# Picnic loaf, beef, pork  2.306 mg  ...  16.64 g               6.070 g
#
#                         monounsaturated_fatty_acids  \
# name
# Picnic loaf, beef, pork                     7.680 g
#
#                         polyunsaturated_fatty_acids fatty_acids_total_trans  \
# name
# Picnic loaf, beef, pork                     1.890 g                38.00 mg
#
#                         alcohol     ash caffeine theobromine    water
# name
# Picnic loaf, beef, pork       0  3.48 g        0           0  60.20 g
#
# [1 rows x 75 columns]

# %%
nutrition.sample(n = 3)
# Out:
#                                                    serving_size  calories  \
# name
# Beef, grilled, cooked, choice, trimmed to 1/8" ...        100 g       217
# Beef, broiled, cooked, all grades, trimmed to 0...        100 g       205
# Fast Foods, meat and skin with breading, Drumst...        100 g       267
#
#                                                    total_fat saturated_fat  \
# name
# Beef, grilled, cooked, choice, trimmed to 1/8" ...       11g          4.6g
# Beef, broiled, cooked, all grades, trimmed to 0...       10g          3.9g
# Fast Foods, meat and skin with breading, Drumst...       17g          4.5g
#
#                                                    cholesterol     sodium  \
# name
# Beef, grilled, cooked, choice, trimmed to 1/8" ...        81mg   68.00 mg
# Beef, broiled, cooked, all grades, trimmed to 0...        85mg   76.00 mg
# Fast Foods, meat and skin with breading, Drumst...       111mg  591.00 mg
#
# ...

# %%
nutrition.sample(frac = 0.03)
# Out:
#                                                    serving_size  calories  \
# name
# Chicken, roasted, cooked, meat only, thigh, bro...        100 g       179
# Syrups, dark, corn                                        100 g       286
# Asparagus, drained solids, canned                         100 g        19
# CAMPBELL'S Soup on the Go, Creamy Broccoli Soup           100 g        52
# Cocoa, HERSHEY'S European Style Cocoa, unsweete...        100 g       410
# ...                                                         ...       ...
# Tortilla, includes plain and from mutton sandwi...        100 g       237
# Beef, raw, select, trimmed to 0" fat, separable...        100 g       135
# Winged bean, with salt, drained, boiled, cooked...        100 g        37
# Beverages, with chicory, instant, coffee                  100 g       355
# MURRAY, Duplex Creme Sandwich Cookies                     100 g       475
#
# ...

# %%
# Sampling with replacement or weights

# %%
nutrition.sample(n = 5, replace = True)
# Out:
#                                                    serving_size  calories  \
# name
# Cereals ready-to-eat, KRETSCHMER Honey Crunch W...        100 g       372
# Olive loaf, pork                                          100 g       235
# Pork, braised, with added solution cooked, sepa...        100 g       227
# Snacks, plain, rice cracker brown rice                    100 g       387
# DENNY'S, coleslaw                                         100 g       183
#
#                                                    total_fat saturated_fat  \
# name
# Cereals ready-to-eat, KRETSCHMER Honey Crunch W...      7.8g          1.4g
# Olive loaf, pork                                         17g          5.9g
# Pork, braised, with added solution cooked, sepa...       12g          4.6g
# Snacks, plain, rice cracker brown rice                  2.8g          0.6g
# DENNY'S, coleslaw                                        15g          2.3g
#
# ...

# %%
#DataFrame Axes

# %%
nutrition.axes
# Out:
# [Index(['Cornstarch', 'Nuts, pecans', 'Eggplant, raw', 'Teff, uncooked',
#         'Sherbet, orange', 'Cauliflower, raw', 'Taro leaves, raw',
#         'Lamb, raw, ground', 'Cheese, camembert', 'Vegetarian fillets',
#         ...
#         'Beef, braised, cooked, all grades, trimmed to 1/8" fat, separable lean and fat, flat half, brisket',
#         'Beef, raw, select, trimmed to 1/8" fat, separable lean only, lip-on, boneless, rib eye steak/roast',
#         'Beef, raw, choice, trimmed to 1/8" fat, separable lean only, lip-on, boneless, rib eye steak/roast',
#         'Oil, uses similar to 95 degree hard butter, confection fat, palm kernel (hydrogenated), industrial',
#         'Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round steak, round',
#         'Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round',
# ...

# %%
nutrition.index[5]
# Out:
# 'Cauliflower, raw'

# %%
nutrition.axes[1]
# Out:
# Index(['serving_size', 'calories', 'total_fat', 'saturated_fat', 'cholesterol',
#        'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
# ...

# %%
nutrition.axes[1][6]
# Out:
# 'choline'

# %%
nutrition.columns[6]
# Out:
# 'choline'

# %%
#Changing the index

# %%
nutrition.head(3)
# Out:
#               serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch           100 g       381      0.1g           NaN           0
# Nuts, pecans         100 g       691       72g          6.2g           0
# Eggplant, raw        100 g        25      0.2g           NaN           0
#
#                 sodium  choline     folate folic_acid    niacin  ...      fat  \
# name                                                             ...
# Cornstarch     9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...   0.05 g
# Nuts, pecans   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...  71.97 g
# Eggplant, raw  2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...   0.18 g
#
#               saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch                  0.009 g                     0.016 g
# Nuts, pecans                6.180 g                    40.801 g
# Eggplant, raw               0.034 g                     0.016 g
#
# ...

# %%
# verify integrity : Check if the index col has unique values

# %%
nutrition.set_index('folic_acid', drop = False, append = True, verify_integrity = True).head()
# Out:
#                            serving_size  calories total_fat saturated_fat  \
# name            folic_acid
# Cornstarch      0.00 mcg          100 g       381      0.1g           NaN
# Nuts, pecans    0.00 mcg          100 g       691       72g          6.2g
# Eggplant, raw   0.00 mcg          100 g        25      0.2g           NaN
# Teff, uncooked  0                 100 g       367      2.4g          0.4g
# Sherbet, orange 0.00 mcg          100 g       144        2g          1.2g
#
#                            cholesterol    sodium  choline     folate  \
# name            folic_acid
# Cornstarch      0.00 mcg             0   9.00 mg   0.4 mg   0.00 mcg
# Nuts, pecans    0.00 mcg             0   0.00 mg  40.5 mg  22.00 mcg
# Eggplant, raw   0.00 mcg             0   2.00 mg   6.9 mg  22.00 mcg
# Teff, uncooked  0                    0  12.00 mg  13.1 mg          0
# Sherbet, orange 0.00 mcg           1mg  46.00 mg   7.7 mg   4.00 mcg
#
# ...

# %%
# Extacting from Dataframes by Label

# %%
nutrition.head(3)
# Out:
#               serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch           100 g       381      0.1g           NaN           0
# Nuts, pecans         100 g       691       72g          6.2g           0
# Eggplant, raw        100 g        25      0.2g           NaN           0
#
#                 sodium  choline     folate folic_acid    niacin  ...      fat  \
# name                                                             ...
# Cornstarch     9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...   0.05 g
# Nuts, pecans   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...  71.97 g
# Eggplant, raw  2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...   0.18 g
#
#               saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch                  0.009 g                     0.016 g
# Nuts, pecans                6.180 g                    40.801 g
# Eggplant, raw               0.034 g                     0.016 g
#
# ...

# %%
nutrition.head(5)
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
nutrition.loc['Cornstarch':'Sherbet, orange']
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
nutrition.loc['Cornstarch':'Sherbet, orange', 'cholesterol': 'niacin']
# Out:
#                 cholesterol    sodium  choline     folate folic_acid    niacin
# name
# Cornstarch                0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg
# Nuts, pecans              0   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg
# Eggplant, raw             0   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg
# Teff, uncooked            0  12.00 mg  13.1 mg          0          0  3.363 mg
# Sherbet, orange         1mg  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg

# %%
#Extraction by position

# %%
nutrition.head(4)
# Out:
#                serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch            100 g       381      0.1g           NaN           0
# Nuts, pecans          100 g       691       72g          6.2g           0
# Eggplant, raw         100 g        25      0.2g           NaN           0
# Teff, uncooked        100 g       367      2.4g          0.4g           0
#
#                   sodium  choline     folate folic_acid    niacin  ...  \
# name                                                               ...
# Cornstarch       9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans     0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw    2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked  12.00 mg  13.1 mg          0          0  3.363 mg  ...
#
#                     fat saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch       0.05 g               0.009 g                     0.016 g
# ...

# %%
nutrition.iloc[3]
# Out:
# serving_size      100 g
# calories            367
# total_fat          2.4g
# saturated_fat      0.4g
# cholesterol           0
#                   ...
# alcohol               0
# ash              2.37 g
# caffeine              0
# theobromine           0
# water            8.82 g
# Name: Teff, uncooked, Length: 75, dtype: object

# %%
nutrition.iloc[3, :]
# Out:
# serving_size      100 g
# calories            367
# total_fat          2.4g
# saturated_fat      0.4g
# cholesterol           0
#                   ...
# alcohol               0
# ash              2.37 g
# caffeine              0
# theobromine           0
# water            8.82 g
# Name: Teff, uncooked, Length: 75, dtype: object

# %%
nutrition.iloc[3:9, 3:]
# Out:
#                   saturated_fat cholesterol     sodium  choline      folate  \
# name
# Teff, uncooked             0.4g           0   12.00 mg  13.1 mg           0
# Sherbet, orange            1.2g         1mg   46.00 mg   7.7 mg    4.00 mcg
# Cauliflower, raw           0.1g           0   30.00 mg  44.3 mg   57.00 mcg
# Taro leaves, raw           0.2g           0    3.00 mg  12.8 mg  126.00 mcg
# Lamb, raw, ground           10g        73mg   59.00 mg  69.3 mg   18.00 mcg
# Cheese, camembert           15g        72mg  842.00 mg  15.4 mg   62.00 mcg
#
#                   folic_acid    niacin pantothenic_acid riboflavin   thiamin  \
# name
# Teff, uncooked             0  3.363 mg         0.942 mg   0.270 mg  0.390 mg
# Sherbet, orange     0.00 mcg  0.063 mg         0.224 mg   0.097 mg  0.027 mg
# Cauliflower, raw    0.00 mcg  0.507 mg         0.667 mg   0.060 mg  0.050 mg
# Taro leaves, raw    0.00 mcg  1.513 mg         0.084 mg   0.456 mg  0.209 mg
# ...

# %%
# Single Value access with .at and .iat
nutrition.head(5)
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
nutrition.iat[2, 2]
# Out:
# '0.2g'

# %% [markdown]
# #Skill Challenge

# %%
nutri_mini = nutrition.sample(10)

# %%
nutri_mini.head(4)
# Out:
#                                                    serving_size  calories  \
# name
# Egg, pasteurized, frozen, raw, whole                      100 g       147
# Lamb, broiled, cooked, choice, trimmed to 1/8" ...        100 g       340
# Seal, partially dried (Alaska Native), meat, be...        100 g       270
# Spices, dried, parsley                                    100 g       292
#
#                                                    total_fat saturated_fat  \
# name
# Egg, pasteurized, frozen, raw, whole                     10g          3.4g
# Lamb, broiled, cooked, choice, trimmed to 1/8" ...       27g           11g
# Seal, partially dried (Alaska Native), meat, be...      2.3g           NaN
# Spices, dried, parsley                                  5.5g          1.4g
#
#                                                    cholesterol     sodium  \
# name
# Egg, pasteurized, frozen, raw, whole                     372mg  128.00 mg
# ...

# %%
nutri_mini[
    ['total_fat', 'cholesterol']
]
# Out:
#                                                    total_fat cholesterol
# name
# Beverages, brewed, other than chamomile, herb, tea        0g           0
# Babyfood, dry, with honey, oatmeal, cereal                7g           0
# KEEBLER, bite size, Rainbow Chocolate Chip Cook...       24g         3mg
# Lamb, raw, separable lean and fat, bone-in, leg...       15g        67mg
# Chicken, roasted, cooked, meat only, wing, broi...      8.1g        85mg
# Agutuk, fish/berry with seal oil (Alaskan ice c...       32g        10mg
# Beef, braised, cooked, select, trimmed to 0" fa...       19g        95mg
# Turkey from whole, roasted, cooked, with added ...      5.6g        76mg
# KELLOGG'S, Frosted Confetti Cake Toaster Pastri...      7.4g           0
# Wheat flours, unenriched, bread                         1.7g           0

# %%
nutri_mini.loc[:, ['total_fat', 'cholesterol']]
# Out:
#                                                    total_fat cholesterol
# name
# Egg, pasteurized, frozen, raw, whole                     10g       372mg
# Lamb, broiled, cooked, choice, trimmed to 1/8" ...       27g        98mg
# Seal, partially dried (Alaska Native), meat, be...      2.3g           0
# Spices, dried, parsley                                  5.5g           0
# MORNINGSTAR FARMS Mediterranean Chickpea, unpre...      6.5g         1mg
# Pork, broiled, cooked, separable lean and fat, ...       11g        77mg
# Mung beans, raw, mature seeds                           1.2g           0
# Pie fillings, low calorie, cherry                       0.2g           0
# BEAR NAKED, Fruit & Nut Cookies                          21g           0
# CHICK-FIL-A, chicken sandwich                            11g        35mg

# %%
nutri_mini.columns
# Out:
# Index(['serving_size', 'calories', 'total_fat', 'saturated_fat', 'cholesterol',
#        'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
# ...

# %%
for i in range(len(nutri_mini.columns)):
  print(i+1, nutri_mini.columns[i])
# Out:
# 1 serving_size
# 2 calories
# 3 total_fat
# 4 saturated_fat
# 5 cholesterol
# 6 sodium
# 7 choline
# 8 folate
# 9 folic_acid
# 10 niacin
# 11 pantothenic_acid
# 12 riboflavin
# 13 thiamin
# 14 vitamin_a
# 15 vitamin_a_rae
# 16 carotene_alpha
# 17 carotene_beta
# 18 cryptoxanthin_beta
# 19 lutein_zeaxanthin
# 20 lucopene
# 21 vitamin_b12
# 22 vitamin_b6
# 23 vitamin_c
# 24 vitamin_d
# 25 vitamin_e
# 26 tocopherol_alpha
# 27 vitamin_k
# 28 calcium
# 29 copper
# 30 irom
# 31 magnesium
# 32 manganese
# 33 phosphorous
# 34 potassium
# 35 selenium
# 36 zink
# 37 protein
# 38 alanine
# 39 arginine
# 40 aspartic_acid
# 41 cystine
# 42 glutamic_acid
# 43 glycine
# 44 histidine
# 45 hydroxyproline
# 46 isoleucine
# 47 leucine
# 48 lysine
# 49 methionine
# 50 phenylalanine
# 51 proline
# 52 serine
# 53 threonine
# 54 tryptophan
# 55 tyrosine
# 56 valine
# 57 carbohydrate
# 58 fiber
# 59 sugars
# 60 fructose
# 61 galactose
# 62 glucose
# 63 lactose
# 64 maltose
# 65 sucrose
# 66 fat
# ...

# %%
nutri_mini.iloc[:3, 22:]
# Out:
#                                                    vitamin_c  vitamin_d  \
# name
# Egg, pasteurized, frozen, raw, whole                  0.0 mg  105.00 IU
# Lamb, broiled, cooked, choice, trimmed to 1/8" ...    0.0 mg          0
# Seal, partially dried (Alaska Native), meat, be...    0.0 mg          0
#
#                                                    vitamin_e tocopherol_alpha  \
# name
# Egg, pasteurized, frozen, raw, whole                 0.72 mg          0.72 mg
# Lamb, broiled, cooked, choice, trimmed to 1/8" ...         0                0
# Seal, partially dried (Alaska Native), meat, be...   0.07 mg          0.07 mg
#
#                                                    vitamin_k   calcium  \
# name
# Egg, pasteurized, frozen, raw, whole                 0.3 mcg  62.00 mg
# Lamb, broiled, cooked, choice, trimmed to 1/8" ...         0  18.00 mg
# Seal, partially dried (Alaska Native), meat, be...   0.0 mcg   9.00 mg
#
# ...

# %%
nutrition.iat[3, 3]
# Out:
# '0.4g'

# %% [markdown]
# #Astype() - Convert a datatype to another

# %%
df
# Out:
#       name  age  marital_status
# 0   Althaf   20           False
# 1  Bhushan   25           False
# 2  Shubham   30           False

# %%
df.age
# Out:
# 0    20
# 1    25
# 2    30
# Name: age, dtype: int64

# %%
df.age.astype(float)
# Out:
# 0    20.0
# 1    25.0
# 2    30.0
# Name: age, dtype: float64

# %%
df.astype(
    {'age': float}
)
# Out:
#       name   age  marital_status
# 0   Althaf  20.0           False
# 1  Bhushan  25.0           False
# 2  Shubham  30.0           False

# %%
# Dataframe replace() + A glimplse at regex

# %%
nutrition.head(5)
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
dfm = nutrition.iloc[:6, :1]

# %%
dfm
# Out:
#                  serving_size
# name
# Cornstarch              100 g
# Nuts, pecans            100 g
# Eggplant, raw           100 g
# Teff, uncooked          100 g
# Sherbet, orange         100 g
# Cauliflower, raw        100 g

# %%
dfm.replace(to_replace = '100 g', value = 100)
# Out:
#                   serving_size
# name
# Cornstarch                 100
# Nuts, pecans               100
# Eggplant, raw              100
# Teff, uncooked             100
# Sherbet, orange            100
# Cauliflower, raw           100

# %%
#regex : regualar expression

# %%
dfm.replace('\sg', '', regex = True)
# Out:
#                  serving_size
# name
# Cornstarch                100
# Nuts, pecans              100
# Eggplant, raw             100
# Teff, uncooked            100
# Sherbet, orange           100
# Cauliflower, raw          100

# %%
#Part 1 : Collecting the Units

# %%
nutrition.head(5)
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
values = nutrition.replace('[a-zA-Z]', '', regex = True)
units = nutrition.replace('[^a-zA-Z]', '', regex = True)

# %%
values.mode()
# Out:
#   serving_size  calories total_fat saturated_fat cholesterol sodium choline  \
# 0         100        884         0           0.1           0  0.00        0
#
#   folate folic_acid niacin  ...    fat saturated_fatty_acids  \
# 0      0      0.00       0  ...  0.00                 0.000
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           0                           0
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine  water
# 0                   0.00     0.0    0    0.00        0.00   2.50
#
# [1 rows x 75 columns]

# %%
units = units.mode()
units
# Out:
#   serving_size  calories total_fat saturated_fat cholesterol sodium choline  \
# 0            g       884         g             g          mg     mg      mg
#
#   folate folic_acid niacin  ... fat saturated_fatty_acids  \
# 0    mcg        mcg     mg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine  water
# 0                      mg       g   g       mg          mg      g
#
# [1 rows x 75 columns]

# %%
values.cholesterol.value_counts()
# Out:
# 0      4079
# 1       183
# 4       154
# 2       149
# 7        85
#        ...
# 648       1
# 844       1
# 252       1
# 852       1
# 211       1
# Name: cholesterol, Length: 313, dtype: int64

# %%
# Rename() Method

# %%
nutrition.head(5)
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
df
# Out:
#       name   age marital_status
# 0   Althaf  20.0          False
# 1      NaN   NaN            NaN
# 2  Shubham   NaN          False

# %%
df.rename(index={0:'Index_Value1', 1:'Index_Value2', 2:'Index_Value3'})
# Out:
#                  name   age marital_status
# Index_Value1   Althaf  20.0          False
# Index_Value2      NaN   NaN            NaN
# Index_Value3  Shubham   NaN          False

# %%
df.rename(columns = {'name':'Name', 'age':'Age', 'marital_status':'Marital_Status'})
# Out:
#       Name   Age Marital_Status
# 0   Althaf  20.0          False
# 1      NaN   NaN            NaN
# 2  Shubham   NaN          False

# %%
df.rename(columns =  {'name':'Name', 'age':'Age', 'marital_status':'Marital_Status'}, index = {0:'1', 1:'2', 2:'3'}, inplace = False)
# Out:
#       Name   Age Marital_Status
# 1   Althaf  20.0          False
# 2      NaN   NaN            NaN
# 3  Shubham   NaN          False

# %%
df.rename(mapper = {'name': 'Names'}, axis = 1)
# Out:
#      Names   age marital_status
# 0   Althaf  20.0          False
# 1      NaN   NaN            NaN
# 2  Shubham   NaN          False

# %%
# Dataframe dropna()

# %%
df
# Out:
#       name   age marital_status
# 0   Althaf  20.0          False
# 1      NaN   NaN            NaN
# 2  Shubham   NaN          False

# %%
df.loc[2, 'age'] = np.nan

# %%
df.loc[1, :] = np.nan

# %%
df
# Out:
#       name   age marital_status
# 0   Althaf  20.0          False
# 1      NaN   NaN            NaN
# 2  Shubham   NaN          False

# %%
df.dropna()
# Out:
#      name   age marital_status
# 0  Althaf  20.0          False

# %%
df
# Out:
#       name   age marital_status
# 0   Althaf  20.0          False
# 1      NaN   NaN            NaN
# 2  Shubham   NaN          False

# %%
df.dropna(how = 'any', axis = 0)
# Out:
#      name   age marital_status
# 0  Althaf  20.0          False

# %%
df.dropna(how = 'all', axis = 0)
# Out:
#       name   age marital_status
# 0   Althaf  20.0          False
# 2  Shubham   NaN          False

# %%
#thresh

# %%
df.dropna(thresh = 3, axis = 0)
# Out:
#      name   age marital_status
# 0  Althaf  20.0          False

# %%
df
# Out:
#       name   age marital_status
# 0   Althaf  20.0          False
# 1      NaN   NaN            NaN
# 2  Shubham   NaN          False

# %% [markdown]
# Merging units with column names

# %%
nutrition.head(5)
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
units.mode()
# Out:
#   serving_size  calories total_fat saturated_fat cholesterol sodium choline  \
# 0            g       884         g             g          mg     mg      mg
#
#   folate folic_acid niacin  ... fat saturated_fatty_acids  \
# 0    mcg        mcg     mg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine  water
# 0                      mg       g   g       mg          mg      g
#
# [1 rows x 75 columns]

# %%
values.mode()
# Out:
#   serving_size  calories total_fat saturated_fat cholesterol sodium choline  \
# 0         100        884         0           0.1           0  0.00        0
#
#   folate folic_acid niacin  ...    fat saturated_fatty_acids  \
# 0      0      0.00       0  ...  0.00                 0.000
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           0                           0
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine  water
# 0                   0.00     0.0    0    0.00        0.00   2.50
#
# [1 rows x 75 columns]

# %%
for k in units:
  print(k, end = ", ")
# Out:
# serving_size, calories, total_fat, saturated_fat, cholesterol, sodium, choline, folate, folic_acid, niacin, pantothenic_acid, riboflavin, thiamin, vitamin_a, vitamin_a_rae, carotene_alpha, carotene_beta, cryptoxanthin_beta, lutein_zeaxanthin, lucopene, vitamin_b12, vitamin_b6, vitamin_c, vitamin_d, vitamin_e, tocopherol_alpha, vitamin_k, calcium, copper, irom, magnesium, manganese, phosphorous, potassium, selenium, zink, protein, alanine, arginine, aspartic_acid, cystine, glutamic_acid, glycine, histidine, hydroxyproline, isoleucine, leucine, lysine, methionine, phenylalanine, proline, serine, threonine, tryptophan, tyrosine, valine, carbohydrate, fiber, sugars, fructose, galactose, glucose, lactose, maltose, sucrose, fat, saturated_fatty_acids, monounsaturated_fatty_acids, polyunsaturated_fatty_acids, fatty_acids_total_trans, alcohol, ash, caffeine, theobromine, water,

# %%
for k in units:
  print(units[k].at[0])
# Out:
# g
# 884
# g
# g
# mg
# mg
# mg
# mcg
# mcg
# mg
# mg
# mg
# mg
# IU
# mcg
# mcg
# mcg
# mcg
# mcg
# 0
# mcg
# mg
# mg
# IU
# mg
# mg
# mcg
# mg
# mg
# mg
# mg
# mg
# mg
# mg
# mcg
# mg
# g
# g
# g
# g
# g
# g
# g
# g
#
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
#
#
#
#
#
#
# g
# g
# g
# g
# mg
# g
# g
# mg
# mg
# g

# %%
units = units.replace('', np.nan).dropna(axis = 1)

# %%
units
# Out:
#   serving_size  calories total_fat saturated_fat cholesterol sodium choline  \
# 0            g       884         g             g          mg     mg      mg
#
#   folate folic_acid niacin  ... fat saturated_fatty_acids  \
# 0    mcg        mcg     mg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine  water
# 0                      mg       g   g       mg          mg      g
#
# [1 rows x 68 columns]

# %%
mapper = {
    k:k+"_"+ str(units[k].at[0]) for k in units
}

# %%
mapper
# Out:
# {'serving_size': 'serving_size_g',
#  'calories': 'calories_884',
#  'total_fat': 'total_fat_g',
#  'saturated_fat': 'saturated_fat_g',
#  'cholesterol': 'cholesterol_mg',
#  'sodium': 'sodium_mg',
#  'choline': 'choline_mg',
#  'folate': 'folate_mcg',
#  'folic_acid': 'folic_acid_mcg',
#  'niacin': 'niacin_mg',
#  'pantothenic_acid': 'pantothenic_acid_mg',
#  'riboflavin': 'riboflavin_mg',
#  'thiamin': 'thiamin_mg',
#  'vitamin_a': 'vitamin_a_IU',
#  'vitamin_a_rae': 'vitamin_a_rae_mcg',
#  'carotene_alpha': 'carotene_alpha_mcg',
#  'carotene_beta': 'carotene_beta_mcg',
#  'cryptoxanthin_beta': 'cryptoxanthin_beta_mcg',
#  'lutein_zeaxanthin': 'lutein_zeaxanthin_mcg',
#  'lucopene': 'lucopene_0',
#  'vitamin_b12': 'vitamin_b12_mcg',
#  'vitamin_b6': 'vitamin_b6_mg',
#  'vitamin_c': 'vitamin_c_mg',
#  'vitamin_d': 'vitamin_d_IU',
#  'vitamin_e': 'vitamin_e_mg',
#  'tocopherol_alpha': 'tocopherol_alpha_mg',
#  'vitamin_k': 'vitamin_k_mcg',
#  'calcium': 'calcium_mg',
# ...

# %%
nutrition.rename(columns = mapper, inplace = True)

# %%
nutrition
# Out:
#                                                    serving_size_g  \
# name
# Cornstarch                                                  100 g
# Nuts, pecans                                                100 g
# Eggplant, raw                                               100 g
# Teff, uncooked                                              100 g
# Sherbet, orange                                             100 g
# ...                                                           ...
# Beef, raw, all grades, trimmed to 0" fat, separ...          100 g
# Lamb, cooked, separable lean only, composite of...          100 g
# Lamb, raw, separable lean and fat, composite of...          100 g
# Beef, raw, all grades, trimmed to 0" fat, separ...          100 g
# Beef, raw, all grades, trimmed to 0" fat, separ...          100 g
#
#                                                     calories_884 total_fat_g  \
# name
# Cornstarch                                                   381        0.1g
# ...

# %%
nutrition.replace('[a-zA-Z]', '', regex = True, inplace = False)
# Out:
#                                                    serving_size_g  \
# name
# Cornstarch                                                   100
# Nuts, pecans                                                 100
# Eggplant, raw                                                100
# Teff, uncooked                                               100
# Sherbet, orange                                              100
# ...                                                           ...
# Beef, raw, all grades, trimmed to 0" fat, separ...           100
# Lamb, cooked, separable lean only, composite of...           100
# Lamb, raw, separable lean and fat, composite of...           100
# Beef, raw, all grades, trimmed to 0" fat, separ...           100
# Beef, raw, all grades, trimmed to 0" fat, separ...           100
#
#                                                     calories_884 total_fat_g  \
# name
# Cornstarch                                                   381         0.1
# ...

# %%
nutrition.head(5)
# Out:
#                 serving_size_g  calories_884 total_fat_g saturated_fat_g  \
# name
# Cornstarch               100 g           381        0.1g             NaN
# Nuts, pecans             100 g           691         72g            6.2g
# Eggplant, raw            100 g            25        0.2g             NaN
# Teff, uncooked           100 g           367        2.4g            0.4g
# Sherbet, orange          100 g           144          2g            1.2g
#
#                 cholesterol_mg sodium_mg choline_mg folate_mcg folic_acid_mcg  \
# name
# Cornstarch                   0   9.00 mg     0.4 mg   0.00 mcg       0.00 mcg
# Nuts, pecans                 0   0.00 mg    40.5 mg  22.00 mcg       0.00 mcg
# Eggplant, raw                0   2.00 mg     6.9 mg  22.00 mcg       0.00 mcg
# Teff, uncooked               0  12.00 mg    13.1 mg          0              0
# Sherbet, orange            1mg  46.00 mg     7.7 mg   4.00 mcg       0.00 mcg
#
# ...

# %%
nutrition.info

# %%
nutrition.dtypes.value_counts()
# Out:
# object    73
# int64      2
# dtype: int64
